# %% [markdown]
# <center><font color=#555555><font size=6> Proyecto final </font> <br> <br>
#
# <center><font color=#555555><font size=5> Proyecto 2: Análisis Técnico </font> <br> <br> <br> <br>
#
# <center><font color=#555555><font size=4> Andrés Ramírez Villanueva </font> <br> <br>
#
# <center><font color=#555555><font size=4>    Carolina Barba Anaya </font> <br> <br>
#
# <center><font color=#555555><font size=4>    Gabriela Ivonne Montoya Ortiz </font> <br> <br>
#
# <center><font color=#555555><font size=4>    Andrés González Luna Diaz del Castillo </font> <br> <br>
#
#
# <center> <font color= #555555> <font size = 4> 05.2023 </a> | <font color= #555555> <font size = 4> Repository: <a href='https://github.com/andres1999iteso/ProyectoFinal'>Link</a></font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <center> <font color= #555555> <font size = 6> Análisis técnico </font> <br> <br> <font color= #555555>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# <br>

# %% [markdown]
# <font color= #555555> <font size = 4> Abstract </font>

# %% [markdown]
# <font color= #6B6B6B> <font size = 3>  Utilizar entre 2 y 4 estudios técnicos como herramientas para la generación de oportunidades de trading, lo que equivale a utilizar análisis técnico para los criterios 1 y sobretodo el 2. </font>

# %% [markdown]
# <br>

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6> Introducción </font>

# %% [markdown]
# Un trader discrecinario tiene un set de reglas y principios que sigue para invertir. Conforme avanza el tiempo y obtiene más experiencia, el trader modifica o reemplaza dichas reglas para irlas ajustando a la realidad de los mercados. Depende de cada trader que tan riguroso siguiendo estas reglas. El trader discrecionario estudia señales en los "charts" y luego hace una decisión de comprar o vender el activo. Por lo general estas señales que buscan, creen que son precursorasas a eventos. Por ejemplo, un trader podría creer que cuando baja la acción de Apple, a los pocos minutos (o segundos) sube la acción de Microsoft porque los ETFs tienen que rebalancearse. Entonces el trader se le podría adelantar al mercado y generar una ganancia. El riesgo en el trading discrecionario es que están involucadras las emociones del trader. Mientras tanto, en el trading algoritmico, no existe este riesgo. En el trading algoritmicio se ejecuta una orden compra o venta cuando se cumplen ciertas reglas. El riesgo con esto es que si el mercado empieza comportarse en maneras extreñas, puede que estás reglas sean cumplidas, pero no sean buenos trades y el trader pierda dinero. Por ejemplo, en black monday cuando la bolsa se cayó porque se empezaron a ejectuar ordenes automatizadas que no tenían freno.

# %% [markdown]
# # <font color= #6B6B6B> 2. Install/Load Packages and Depedencies </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>

# %% [markdown]
# ## <font color= #6B6B6B> 2.1 Python Packages </font> <font color= #555555>

# %% [markdown]
# In order to run this notebook, it is necessary to have installed and/or have the _requirements.txt_ file with the following:

# %%
import data as dt
import functions as fun
# Out:
# 24831
# 24897
# 25001
# 25021
#        MAD1     MAD2      MAD3
# 0  2.150755  2.09363  1.298156
#   Operación
# 0    Compra
# 1     Venta
# 2    Compra
# 3     Venta
# 4    Compra
# 5     Venta
# 6    Compra

# %% [markdown]
# ## <font color= #6B6B6B> 2.2 Files Dependencies </font> <font color= #555555>

# %% [markdown]
# The following are the file dependencies that are needed to run this notebook:

# %% [markdown]
# ## <font color= #6E6E6E> 2.3 Install Packages</font>

# %%
# %%capture

# Install all the pip packages in the requirements.txt
import sys
# !{sys.executable} -m pip install -r requirements.txt

# %% [markdown]
# <br>

# %% [markdown]
# # Sección 1

# %% [markdown]
# ## Aspectos financieros y estadísticos

# %% [markdown]
# RSI (Relative Strength Index)
# Es un indicador técnico que se se utiliza para medir la fuerza relativa de una acción, un índice o cualquier otro instrumento financiero, comparando la magnitud de sus ganancias recientes con la magnitud de sus pérdidas recientes.
#
# Criterios a considerar:
# 1. Condicione de entrada = 30 y salida del mercado = 70
# 2. Capital inicial: 100,000 y riesgo máximo por operación (pérdida máximo): 1,000 usd
# 3. Realizar un backtesting.
# 4. Monitorear y ajustar el sistema de trading.

# %% [markdown]
# Indicador económico a utilizar: GDP

# %% [markdown]
# El Gross Domestic Product Annualized es un indicador económico importante que proporciona una medida de la actividad económica general y el desempeño de un país. Representa el valor total de todos los bienes y servicios producidos dentro de las fronteras de un país. Esto es crucial porque ofrece información sobre el tamaño y la tasa de crecimiento de una economía.
#
# También, sirve como punto de referencia para comparar el desempeño económico de diferentes países o evaluar los cambios dentro de una economía a lo largo del tiempo.
#
# Este abarca varios componentes, incluido el consumo privado, el gasto público, las inversiones y las exportaciones netas. Los cambios en estos componentes pueden indicar cambios en el comportamiento del consumidor, la inversión empresarial, las políticas gubernamentales y la dinámica del comercio internacional.

# %%
#imrimir el head de la data de GDP
dt.indicador.head()
# Out:
#                    timestamp                               name  \
# 0  2020-01-30 13:30:00+00:00  Gross Domestic Product Annualized
# 1  2019-12-20 13:30:00+00:00  Gross Domestic Product Annualized
# 2  2019-11-27 13:30:00+00:00  Gross Domestic Product Annualized
# 3  2019-10-30 12:30:00+00:00  Gross Domestic Product Annualized
# 4  2019-09-26 12:30:00+00:00  Gross Domestic Product Annualized
#
#         currency  actual  consensus  previous
# 0  United States     2.1        2.1       2.1
# 1  United States     2.1        2.1       2.1
# 2  United States     2.1        1.9       1.9
# 3  United States     1.9        1.6       2.0
# 4  United States     2.0        2.0       2.0

# %% [markdown]
# Par de divisas: USDMXN  / EURUSD

# %%
#imrimir el head de las divisas
dt.USDMXN.head()
# Out:
#    Unnamed: 0                 time      open      high       low     close  \
# 0       16844  2020-01-02 00:00:00  18.89565  18.92847  18.82735  18.83095
# 1       16845  2020-01-02 06:00:00  18.89660  18.89867  18.89565  18.89837
# 2       16846  2020-01-02 06:15:00  18.89837  18.90363  18.89767  18.90207
# 3       16847  2020-01-02 06:30:00  18.90207  18.90765  18.90187  18.90637
# 4       16848  2020-01-02 06:45:00  18.90637  18.91307  18.90637  18.91017
#
#    tick_volume  spread  real_volume
# 0        50071       0            0
# 1          182     646     18200000
# 2          375     530     37500000
# 3          241     536     24100000
# 4          531     576     53100000

# %%
dt.EURUSD.head()
# Out:
#    Unnamed: 0                 time     open     high      low    close  \
# 0       16513  2020-01-02 00:00:00  1.12080  1.12140  1.11628  1.11712
# 1       16514  2020-01-02 06:00:00  1.12124  1.12135  1.12117  1.12135
# 2       16515  2020-01-02 06:15:00  1.12135  1.12136  1.12112  1.12114
# 3       16516  2020-01-02 06:30:00  1.12114  1.12115  1.12082  1.12090
# 4       16517  2020-01-02 06:45:00  1.12090  1.12090  1.12002  1.12005
#
#    tick_volume  spread  real_volume
# 0        36043      50            0
# 1         2963      15    444450000
# 2         3639      15    545850000
# 3         3489      15    523350000
# 4         4789      15    718350000

# %% [markdown]
# VALIDACIONES VISUALES

# %% [markdown]
# Se hicieron 5 validaciones en nuestras dos divisas, utilizando el indicador
#
# "RELATIVE STRENGHT INDEX (RSI)"

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Utilizamos la divisa EURUSD con un periodo mensual, utilizando el indicador RELATIVE STRENGHT INDEX, pudimos observar lo siguiente:
#
# 1. En nuestra primera instancia, tuvimos una alerta de compra, ya que hubo un cruce del indíce inferior, indicandonos que la divisa iba a subir, y efectivamente tuvo ese movimiento
#
# 2. En nuestra segunda instancia, tuvimos una alerta de venta, ya que estuvo muy cerca del indíce superior, indicandonos que la divisa iba a caer, lo cuál fue asertivo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Utilizamos la divisa USDMXN con un periodo mensual, utilizando el indicador RELATIVE STRENGHT INDEX, pudimos observar lo siguiente:
#
# 3. En nuestra terceta instancia, tuvimos una alerta de compra, ya que estuvo cerca del indíce inferior indicandonos que la divisa iba a subir, la respuesta fue positiva, sin embargo el movimiento fue pequeño, debido a la volatilidad de esta divisa.
#
# 4. En nuestra cuarta instancia, tuvimos una alerta de venta, ya que hubo un cruce del indíce superior, indicandonos que la divisa iba a caer, lo cuál fue verdadero, pero en un lapso corto
#
# 5. En nuestra quinta instancia, tuvimos una alerta de venta, ya que hubo un cruce del indíce superior, indicandonos que la divisa iba a caer, lo cuál fue verdadero, pero en un lapso corto

# %%
#Imprimi los MAD 'tabla'
dt.tabla.head()
# Out:
#        MAD1     MAD2      MAD3
# 0  2.150755  2.09363  1.298156

# %%
#imprimir 'tabla_rsi'
dt.tabla_rsi.head()
# Out:
#   Operación
# 0    Compra
# 1     Venta
# 2    Compra
# 3     Venta
# 4    Compra

# %% [markdown]
# ## Aspectos computacionales

# %% [markdown]
# ### Parámetros a optimizar

# %% [markdown]
# Parámetro: 1
# Nombre: Entrada
# Descripción: Valor minimo de entrada
# Tipo de valor: numérico
# Rango de valores: 1 - 30
# Tamaño de paso mínimo: 1

# %% [markdown]
# Parámetro: 2
# Nombre: Stop Loss
# Descripción: El precio en el que está nuestro Stop Loss
# Tipo de valor: numérico
# Rango de valores: 1 - 1000
# Tamaño de paso mínimo: 1

# %% [markdown]
# Parámetro: 3
# Nombre: Salida
# Descripción: Valor maximo de salida
# Tipo de valor: numérico
# Rango de valores: 31 - 70
# Tamaño de paso mínimo: 1

# %% [markdown]
# ### Espacio de búsqueda

# %% [markdown]
# Como tenemos tres parametros el espacio de busqueda seria de
# (30-1+1) * (1000-1+1) * (70-31+1) = 30 * 1000 * 40 = **1,200,000**

# %% [markdown]
# ### Tiempo de búsqueda exhausitva

# %% [markdown]
# Asignando 0.5 segundos de tiempo transcurrido cargando el código realizando una búsqueda exhaustiva sería de 600,000 segundos lo cual es igual a **6.94 días**. Esto no es algo eficiente. Es por eso que utilizamos otro método de optimización.

# %% [markdown]
# ### Optimizacion con algoritmos geneticos

# %%
# Poner funcnion de optimizacion

# %%
# Parámetros del algoritmo genético
tamaño_poblacion = 20
num_generaciones = 50
probabilidad_cruce = 0.8
probabilidad_mutacion = 0.2

# Rango de valores para cada parámetro
rango_entrada = (1, 30)
rango_stop_loss = (1, 1000)
rango_salida = (31, 70)

# %%
fun.algoritmo_genetico(tamaño_poblacion, num_generaciones, probabilidad_cruce, probabilidad_mutacion, rango_entrada, rango_stop_loss, rango_salida)

# %%
# Tambien hace falta agregar la funcion de evaluar parametros

# %% [markdown]
# # <font color= #6B6B6B> <font size = 6>  References </font>

# %% [markdown]
# <hr style="border:0.02in solid gray"> </hr>
